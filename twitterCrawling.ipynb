# %%
from twitterscraper.query import query_tweets
from IPython.display import display
import pandas as pd
import datetime

# %%
# !pip install twitterscraper

# %%
for tweet in query_tweets('월드컵',10):
        print(tweet.timestamp) #작성시간
        print(tweet.text)      #트윗내용

# %%
begin_data = dt.date(2021,1,1)
end_date = dt.date(2021,7,1)

limit = 100
lang = 'english'

tweets = query_tweets("notre dame fire", begindate=begin_data, enddate=end_date, limit= limit, lang=lang)

# %%
tweets
# Out:
# []

# %%
for tweet in query_tweets('월드컵',10):
    print(tweet.text)      #트윗내용

# %%
twitterscraper "BTC OR 비트코인" --limit 1000 --output=bit_kor.json --lang ko  -bd 2017-01-01 -ed 2017-06-01
# Out:
#   File "<ipython-input-18-8fde2e24c6e7>", line 1
#     twitterscraper "BTC OR 비트코인" --limit 1000 --output=bit_kor.json --lang ko  -bd 2017-01-01 -ed 2017-06-01
#                    ^
# SyntaxError: invalid syntax

# %%
from twitterscraper import query_tweets
from twitterscraper.query import query_tweets_from_user
import datetime as dt 
import pandas as pd 


begin_date = dt.date(2020,7,1)
end_date = dt.date(2020,7,13)


limit = 100
lang = 'english'

#Use this to search a specific user

user = 'realDonaldTrump'
tweets = query_tweets_from_user(user)
df = pd.DataFrame(t.__dict__ for t in tweets)

df = df.loc[df['screen_name'] == user]

df = df['text']

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'screen_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-f228c7994341> in <module>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-5772b804c290> in <module>
# ----> 1 import twint
#
# ModuleNotFoundError: No module named 'twint'

# %%
# !pip install twint
# Out:
# ...
#   Using cached twint-2.1.20.tar.gz (31 kB)
# ...
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# ...
#   Using cached beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# ...
#   Using cached elasticsearch-7.13.3-py2.py3-none-any.whl (356 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# ...
#   Using cached aiohttp_socks-0.6.0-py3-none-any.whl (9.2 kB)
# ...
#   Using cached schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached geopy-2.2.0-py3-none-any.whl (118 kB)
# ...
#   Using cached fake-useragent-0.1.11.tar.gz (13 kB)
# ...
#   Using cached googletransx-2.4.2.tar.gz (13 kB)
# ...
#   Using cached pycparser-2.20-py2.py3-none-any.whl (112 kB)
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# ...
#   Using cached typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# ...
#   Using cached idna-3.2-py3-none-any.whl (59 kB)
# ...
#   Using cached python_socks-1.2.4-py3-none-any.whl (35 kB)
# ...
#   Using cached soupsieve-2.2.1-py3-none-any.whl (33 kB)
# ...

# %%
import twint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5772b804c290> in <module>
# ----> 1 import twint
#
# ModuleNotFoundError: No module named 'twint'

# %%
# !pip install --user --upgrade -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Obtaining twint from git+https://github.com/twintproject/twint.git@origin/master#egg=twint
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to e:\jupyter\21.07\bmw미팅\src\twint
#   Running command git clone -q https://github.com/twintproject/twint.git 'E:\jupyter\21.07\bmw미팅\src\twint'
#   ERROR: Error [WinError 2] 지정된 파일을 찾을 수 없습니다 while executing command git clone -q https://github.com/twintproject/twint.git 'E:\jupyter\21.07\bmw미팅\src\twint'
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?

# %%
import twint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-5772b804c290> in <module>
# ----> 1 import twint
#
# ModuleNotFoundError: No module named 'twint'

# %%
import datetime
import pandas
import twint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-a734483d3001> in <module>
#       1 import datetime
#       2 import pandas
# ----> 3 import twint
#
# ModuleNotFoundError: No module named 'twint'

# %%
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd
from time import sleep

# %%
begin_data = dt.date(2021,1,1)
end_date = dt.date(2021,7,1)

limit = 100
lang = 'english'

tweets = query_tweets("notre dame fire", begindate=begin_data, enddate=end_date, limit= limit, lang=lang)

# %%
tweets
# Out:
# []

# %%
list_of_tweets = query_tweets('디아블로', begindate=begin_data, enddate=end_date)

# %%
for tweet in list_of_tweets:
    print(tweet.fullname)

# %%
if __name__ == '__main__':
    list_of_tweets = query_tweets("Trump OR Clinton", 10)

    #print the retrieved tweets to the screen:
    for tweet in query_tweets("Trump OR Clinton", 10):
        print(tweet)

    #Or save the retrieved tweets to file:
    file = open(“output.txt”,”w”)
    for tweet in query_tweets("Trump OR Clinton", 10):
        file.write(str(tweet.text.encode('utf-8')))
    file.close()
# Out:
#   File "<ipython-input-22-113a18e79972>", line 9
#     file = open(“output.txt”,”w”)
#                       ^
# SyntaxError: invalid character in identifier

# %%
import datetime  

# twutterscraper 중 query_tweets 활용
from twitterscraper.query import query_tweets

# %%
# 시작일을 2020,3,1로 마지막날을 2020,3,9로 설정
tweets = query_tweets('코로나', begindate=datetime.date(2020,3,1), enddate=datetime.date(2020,3,9))

# %%
corona_tweet = open('./corona_tweets.txt',encoding='utf-8',mode='w')

# %%
for tweet in tweets :
    corona_tweet.write(tweet.username)
    corona_tweet.write(str(tweet.timestamp))
    corona_tweet.write(tweet.text)
    corona_tweet.write("\n")

# %%
corona_tweet.close()

# %%
from twitterscraper.query import query_tweets
from IPython.display import display
import pandas as pd
import datetime

tweets = []
keyword = '코로나바이러스'
cols = ['timestamp','text']

list_of_tweets = query_tweets(keyword, begindate=datetime.date(2021,7,7), enddate=datetime.date(2021,7,14), limit=10)
for tweet in list_of_tweets:
    tweets.append([tweet.timestamp,tweet.text])
    
data_frame = pd.DataFrame(tweets,columns=cols)
display(data_frame)
data_frame.to_csv(keyword+"3.csv", mode='w', encoding="utf-8-sig")
# Out:
# Empty DataFrame
# Columns: [timestamp, text]
# Index: []

# %%
# !pip uninstall twitterscraper
# Out:
# ^C

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# ...

# %%
from twitterscraper.query import query_tweets
from IPython.display import display
import pandas as pd
import datetime

# %%
tweets = []
keyword = '코로나바이러스'
cols = ['timestamp','text']

list_of_tweets = query_tweets(keyword, begindate=datetime.date(2021,7,7), enddate=datetime.date(2021,7,14), limit=10)
for tweet in list_of_tweets:
    tweets.append([tweet.timestamp,tweet.text])
    
data_frame = pd.DataFrame(tweets,columns=cols)
display(data_frame)
data_frame.to_csv(keyword+"3.csv", mode='w', encoding="utf-8-sig")
# Out:
# Empty DataFrame
# Columns: [timestamp, text]
# Index: []

# %%
from twitterscraper.query import query_user_info

# %%
twitter_user = "BTS_twt"
user_info = query_user_info(user= twitter_user)

print("user : "+user_info.user)
print("fullname : "+user_info.full_name)
print("location : "+user_info.location)
print("blog : "+user_info.location)
print("date_joined : "+user_info.date_joined)
print("id : "+user_info.id)
print("num_of_tweets : "+str(user_info.tweets))
print("following : "+str(user_info.following))
print("follower : "+str(user_info.followers))
print("likes : "+str(user_info.likes))
print("lists : "+str(user_info.lists))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-22cf35594ce6> in <module>
#       2 user_info = query_user_info(user= twitter_user)
#       3
# ----> 4 print("user : "+user_info.user)
#       5 print("fullname : "+user_info.full_name)
#       6 print("location : "+user_info.location)
#
# AttributeError: 'NoneType' object has no attribute 'user'

# %%
query_user_info
# Out:
# <function twitterscraper.query.query_user_info(user, use_proxy=True)>

# %%
# !pip uninstall twitterscraper
# Out:
# ^C

# %%
from twitterscraper import query_tweets
from twitterscraper.query import query_tweets_from_user
import datetime as dt 
import pandas as pd 


begin_date = dt.date(2020,7,1)
end_date = dt.date(2020,7,13)


limit = 100
lang = 'english'

#Use this to search a specific user

user = 'realDonaldTrump'
tweets = query_tweets_from_user(user)
df = pd.DataFrame(t.__dict__ for t in tweets)

df = df.loc[df['screen_name'] == user]

df = df['text']

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'screen_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-f228c7994341> in <module>
# ...

# %%
# !pip install -q snscrape

# %%
# Out:
# Number Of Tweets : 0

# %%
max_results = 100

# %%
# Out:
# No Tweets found

# %%
# !pip install twint
# Out:
# ...
#   Using cached twint-2.1.20-py3-none-any.whl
# ...
#   Using cached googletransx-2.4.2-py3-none-any.whl
# ...
#   Using cached cchardet-2.1.7-cp38-cp38-win_amd64.whl (115 kB)
# ...
#   Using cached schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached aiohttp_socks-0.6.0-py3-none-any.whl (9.2 kB)
# ...
#   Using cached aiohttp-3.7.4.post0-cp38-cp38-win_amd64.whl (635 kB)
# ...
#   Using cached fake_useragent-0.1.11-py3-none-any.whl
# ...
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# ...
#   Using cached geopy-2.2.0-py3-none-any.whl (118 kB)
# ...
#   Using cached elasticsearch-7.13.3-py2.py3-none-any.whl (356 kB)
# ...
#   Using cached pycares-4.0.0-cp38-cp38-win_amd64.whl (82 kB)
# ...
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# ...
#   Using cached multidict-5.1.0-cp38-cp38-win_amd64.whl (48 kB)
# ...
#   Using cached yarl-1.6.3-cp38-cp38-win_amd64.whl (125 kB)
# ...
#   Using cached python_socks-1.2.4-py3-none-any.whl (35 kB)
# ...
#   Using cached geographiclib-1.52-py3-none-any.whl (38 kB)
# ...

# %%
import twint

# %%
import twint

c = twint.Config()
c.Username = "noneprivacy"
c.Limit = 100
c.Store_csv = True
c.Output = "none.csv"
c.Lang = "en"
c.Translate = True
c.TranslateDest = "it"
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-36-36b8486bf2dd> in <module>
#       9 c.Translate = True
#      10 c.TranslateDest = "it"
# ---> 11 twint.run.Search(c)
#
# ~\anaconda3\lib\site-packages\twint\run.py in Search(config, callback)
#     325     config.Profile = False
#     326     config.Profile_full = False
# --> 327     run(config, callback)
#     328     if config.Pandas_au:
#     329         storage.panda._autoget("tweet")
#
# ~\anaconda3\lib\site-packages\twint\run.py in run(config, callback)
#     224         raise
#     225
# --> 226     get_event_loop().run_until_complete(Twint(config).main(callback))
#     227
#     228 def Favorites(config):
#
# ~\anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     590         """
#     591         self._check_closed()
# --> 592         self._check_running()
#     593
# ...

# %%
import twittet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-1634518618c9> in <module>
# ----> 1 import twittet
#
# ModuleNotFoundError: No module named 'twittet'

# %%
# !pip install twitter

# %%
import twitter
import snscrape
import os

from datetime import date

# %%
today = date.today()
end_date = today
search_term = 'BTS'
from_date = '2019-01-01'

# %%
os.system(f"snscrape --since {from_date} twitter-search '{search_term} until:{end_date}' > result-tweets.txt")
if os.stat("result-tweets.txt").st_size == 0:
    counter = 0
else:
    df = pd.read_csv('result-tweets.txt', names=['link'])
    counter = df.size

print('Number Of Tweets : '+ str(counter))
# Out:
# Number Of Tweets : 0

# %%
import pandas as pd
import numpy as np
import snscrape.modules.twitter as sntwitter
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'Pfizer'
#Open/create a file to append data to
csvFile = open('pfe_tweets_result.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:en since:2020-01-01 until:2020-10-30 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()
# Out:
# C:\Users\com\anaconda3\lib\json\decoder.py:353: RuntimeWarning: coroutine 'Twint.main' was never awaited
#   obj, end = self.scan_once(s, idx)
# ...

# %%
# Set maximum tweets to pull
maxTweets = 200
# Set what keywords you want your twitter scraper to pull
keyword = 'BMW'
#Open/create a file to append data to
csvFile = open('pfe_tweets_result.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2020-01-01 until:2020-10-30 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
tw_bmw = pd.read_csv("./pfe_tweets_result.csv")

# %%
tw_bmw
# Out:
#                       id                       date  \
# 0    1321937727269449729  2020-10-29 22:11:29+00:00
# 1    1321923951015030784  2020-10-29 21:16:44+00:00
# 2    1321923412944564226  2020-10-29 21:14:36+00:00
# 3    1321918109184188416  2020-10-29 20:53:31+00:00
# 4    1321891323591319552  2020-10-29 19:07:05+00:00
# ..                   ...                        ...
# 196  1317180282001391617  2020-10-16 19:07:05+00:00
# 197  1317152721774931969  2020-10-16 17:17:35+00:00
# 198  1317141873354440708  2020-10-16 16:34:28+00:00
# 199  1317092375127158786  2020-10-16 13:17:47+00:00
# 200  1317075991290785794  2020-10-16 12:12:41+00:00
#
#                                                  tweet
# 0    웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 ...
# 1                     BMW 3시리즈 에어백 결함 리콜, 국내는 3천800여 대
# 2                     송해 해명, 역시 'BMW가 최고지'..고개 숙인 이유는?
# 3    #그ㄹㅐ프ㄱㅔ임꽁머니\n#소셜그ㄹㅐ프ㄱㅔ임주소\n⥏ ⥐ ⥑  ⤶ busTA5,COM...
# 4                                     오~ BMW? ...거 뭔데?
# ...

# %%
# Set maximum tweets to pull
maxTweets = 200
# Set what keywords you want your twitter scraper to pull
keyword = 'BMW 520'
#Open/create a file to append data to
csvFile = open('pfe_tweets_result2.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet'])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2021-01-01 until:2021-12-31 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
tw_bmw520 = pd.read_csv("./pfe_tweets_result2.csv")

# %%
tw_bmw520
# Out:
#                       id                       date  \
# 0    1404480847365873669  2021-06-14 16:48:22+00:00
# 1    1404478996222418948  2021-06-14 16:41:01+00:00
# 2    1404477991132876803  2021-06-14 16:37:01+00:00
# 3    1396115580042682368  2021-05-22 14:47:47+00:00
# 4    1386499312557850630  2021-04-26 01:56:10+00:00
# ..                   ...                        ...
# 130  1232621078045806593  2020-02-26 10:59:00+00:00
# 131  1221464069653159941  2020-01-26 16:05:02+00:00
# 132  1219679837549318145  2020-01-21 17:55:08+00:00
# 133  1219329721328005120  2020-01-20 18:43:54+00:00
# 134  1218667810135494657  2020-01-18 22:53:42+00:00
#
#                                                  tweet
# 0    전륜   자동차  배기가스에서 유독  이물질 발생  그런데bmw는 언론에서 후륜완급...
# 1    모든신체는 신경들이 연결되서 한부분을 못쓰게하면 신경들이 약해지기 때문에다른 한쪽만...
# 2    몸에 신경은  항문도증상이 연결된 모든신체기관에 신경은 다연결됀것 처럼bmw는 페달...
# 3    뒷북쩌네\n  ㄴ어쩌라고\n\n톡으로 뜬금없이 520보내서 먼데 이게 아직 520일...
# 4             드디어 지인분이 K8 기다리다가 BMW520i로 변경. 탁월한 선택이다.
# ...

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'bmw'
#Open/create a file to append data to
csvFile = open('pfe_tweets_result3.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2020-01-01 until:2021-07-18 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
tw_bmw = pd.read_csv("./pfe_tweets_result3.csv")

# %%
tw_bmw
# Out:
#                        id                       date  \
# 0     1416542776301297664  2021-07-17 23:38:10+00:00
# 1     1416538520739405826  2021-07-17 23:21:16+00:00
# 2     1416528562383773698  2021-07-17 22:41:41+00:00
# 3     1416457850642067457  2021-07-17 18:00:42+00:00
# 4     1416454660517359616  2021-07-17 17:48:02+00:00
# ...                   ...                        ...
# 6690  1212270892991963137  2020-01-01 07:14:38+00:00
# 6691  1212225587860738048  2020-01-01 04:14:36+00:00
# 6692  1212218663580782592  2020-01-01 03:47:05+00:00
# 6693  1212202142850699264  2020-01-01 02:41:27+00:00
# 6694  1212161592961318912  2020-01-01 00:00:19+00:00
#
#                                                   tweet
# 0                          나랑 일하면 BMW 탄다 // 오 BMW~ 그먼데?
# 1     자기직전에...엄마한테 붙들려서 자전거 한시간 타고왔다...... 자전거 한시간.....
# 2     웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 ...
# 3     지훊 불면제로에서 썰 푸는거 지짜 젛음 걍 존나 사랑하게 돼 ㅋ ㅋ ㅋ  비슷한 맥...
# ...

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'BTS'
#Open/create a file to append data to
csvFile = open('pfe_tweets_result.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2020-01-01 until:2021-07-18 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
tw_bts = pd.read_csv("./pfe_tweets_result.csv")

# %%
tw_bts
# Out:
#                         id                       date  \
# 0      1321937727269449729  2020-10-29 22:11:29+00:00
# 1      1321923951015030784  2020-10-29 21:16:44+00:00
# 2      1321923412944564226  2020-10-29 21:14:36+00:00
# 3      1321918109184188416  2020-10-29 20:53:31+00:00
# 4      1321891323591319552  2020-10-29 19:07:05+00:00
# ...                    ...                        ...
# 24978  1412787686474096644  2021-07-07 14:56:47+00:00
# 24979  1412787638591889418  2021-07-07 14:56:36+00:00
# 24980  1412787632828870659  2021-07-07 14:56:34+00:00
# 24981  1412787620807991301  2021-07-07 14:56:31+00:00
# 24982  1412787579183800325  2021-07-07 14:56:21+00:00
#
#                                                    tweet
# 0      웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 ...
# 1                       BMW 3시리즈 에어백 결함 리콜, 국내는 3천800여 대
# 2                       송해 해명, 역시 'BMW가 최고지'..고개 숙인 이유는?
# 3      #그ㄹㅐ프ㄱㅔ임꽁머니\n#소셜그ㄹㅐ프ㄱㅔ임주소\n⥏ ⥐ ⥑  ⤶ busTA5,COM...
# ...

# %%
# Set maximum tweets to pull
maxTweets = 20
# Set what keywords you want your twitter scraper to pull
keyword = 'BTS'
#Open/create a file to append data to
csvFile = open('pfe_tweets_result_bts.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id', 'date', 'username', 'url', 'outlinks', 'tcooutlinks', 'outlinksss', 'tweet'])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2020-01-01 until:2021-07-18 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.username, tweet.url, tweet.outlinks, tweet.tcooutlinks, 
                            tweet.outlinksss, tweet.content])
csvFile.close()

# %%
tw_bts = pd.read_csv("./pfe_tweets_result_bts.csv")

# %%
tw_bts
# Out:
#                      id                       date         username  \
# 0   1416548258399260684  2021-07-17 23:59:57+00:00        BelissOT7
# 1   1416548237108985861  2021-07-17 23:59:52+00:00          BlesVJ7
# 2   1416548190338240512  2021-07-17 23:59:41+00:00      alpacapalca
# 3   1416548183354839040  2021-07-17 23:59:39+00:00        Tokyo_twv
# 4   1416548160051322887  2021-07-17 23:59:34+00:00       AlejaO1599
# 5   1416548092304936962  2021-07-17 23:59:18+00:00         lar1caam
# 6   1416548035232899076  2021-07-17 23:59:04+00:00  vCJOEHM0K2B9MNd
# 7   1416548007189762048  2021-07-17 23:58:57+00:00         DiyyanaZ
# 8   1416547934393491460  2021-07-17 23:58:40+00:00         parkgitz
# 9   1416547910041444355  2021-07-17 23:58:34+00:00     Nicole200620
# 10  1416547885064376321  2021-07-17 23:58:28+00:00      NeroLuciana
# 11  1416547865397190658  2021-07-17 23:58:23+00:00      Interludees
# 12  1416547829603049480  2021-07-17 23:58:15+00:00      MineMinkook
# ...

# %%
tw_bts[["tweet"]]
# Out:
#                                                 tweet
# 0   Nam \n[방탄소년단 RM] Daily Tweet for BTS #RM | Bra...
# 1   [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 2   [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 3   [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 4   [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 5   [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 6   마이크드롭 \n991,393,772\n\nI vote @BTS_twt as 2021...
# 7   뮤직비디오를 보고 또 보세요,너무 감정적이야.. #PermissiontoDance....
# 8   [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 9   [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 10  [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 11  [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 12  [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 13  [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 14  [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Rep...
# 15  트친소에 투표글 넣어주세요 plz...\n\n트친소겸 투표글 얼마나 조아요\n\n1...
# ...

# %%
#-*- coding: utf-8 -*-
import re
hashtag_regex = "#([0-9a-zA-Z가-힣]*)"
p = re.compile(hashtag_regex)
test_text = '''
본문에서 #해쉬태그 를 찾아 봅시다.
#어디에 #있나요 #그것이알고싶다
나와라 #짠
'''
r = p.findall(test_text)
print(r)
# Out:
# ['해쉬태그', '어디에', '있나요', '그것이알고싶다', '짠']

# %%
tw_bts["hashtag"] = tw_bts["tweet"].str.findall("#([0-9a-zA-Z가-힣]*)")

# %%
tw_bts["hashtag"]
# Out:
# 0     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 1     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 2     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 3     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 4     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 5     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 6                             [MTVHottest]
# 7                      [PermissiontoDance]
# 8     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 9     [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 10    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 11    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 12    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 13    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 14    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 15                            [MTVHottest]
# 16    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 17    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 18    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 19    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# 20    [RM, 방탄소년단RM, 김남준, Namjoon, BTS, , ]
# Name: hashtag, dtype: object

# %%
tw_bts
# Out:
#                      id                       date         username  \
# 0   1416548258399260684  2021-07-17 23:59:57+00:00        BelissOT7
# 1   1416548237108985861  2021-07-17 23:59:52+00:00          BlesVJ7
# 2   1416548190338240512  2021-07-17 23:59:41+00:00      alpacapalca
# 3   1416548183354839040  2021-07-17 23:59:39+00:00        Tokyo_twv
# 4   1416548160051322887  2021-07-17 23:59:34+00:00       AlejaO1599
# 5   1416548092304936962  2021-07-17 23:59:18+00:00         lar1caam
# 6   1416548035232899076  2021-07-17 23:59:04+00:00  vCJOEHM0K2B9MNd
# 7   1416548007189762048  2021-07-17 23:58:57+00:00         DiyyanaZ
# 8   1416547934393491460  2021-07-17 23:58:40+00:00         parkgitz
# 9   1416547910041444355  2021-07-17 23:58:34+00:00     Nicole200620
# 10  1416547885064376321  2021-07-17 23:58:28+00:00      NeroLuciana
# 11  1416547865397190658  2021-07-17 23:58:23+00:00      Interludees
# 12  1416547829603049480  2021-07-17 23:58:15+00:00      MineMinkook
# ...

# %%
print(tw_bts["tweet"][0])
# Out:
# Nam
# [방탄소년단 RM] Daily Tweet for BTS #RM | Brand Reputation Project | 04.26.2021 | #방탄소년단RM #김남준 #Namjoon #BTS #ナム #ナムジュン

# %%
tw_bts["tweet"]= tw_bts["tweet"].str.replace(pat=r'#([0-9a-zA-Z가-힣]*)', repl=r"", regex=True)

# %%
print(tw_bts["tweet"][0])
# Out:
# Nam
# [방탄소년단 RM] Daily Tweet for BTS  | Brand Reputation Project | 04.26.2021 |     ナム ナムジュン

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'BMW'
#Open/create a file to append data to
csvFile = open('pfe_tweets_result_bmw.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2020-01-01 until:2021-07-18 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
tw_bmw = pd.read_csv("./pfe_tweets_result_bmw.csv")

# %%
tw_bmw
# Out:
#                        id                       date  \
# 0     1416542776301297664  2021-07-17 23:38:10+00:00
# 1     1416538520739405826  2021-07-17 23:21:16+00:00
# 2     1416528562383773698  2021-07-17 22:41:41+00:00
# 3     1416457850642067457  2021-07-17 18:00:42+00:00
# 4     1416454660517359616  2021-07-17 17:48:02+00:00
# ...                   ...                        ...
# 6619  1212270892991963137  2020-01-01 07:14:38+00:00
# 6620  1212225587860738048  2020-01-01 04:14:36+00:00
# 6621  1212218663580782592  2020-01-01 03:47:05+00:00
# 6622  1212202142850699264  2020-01-01 02:41:27+00:00
# 6623  1212161592961318912  2020-01-01 00:00:19+00:00
#
#                                                   tweet
# 0                          나랑 일하면 BMW 탄다 // 오 BMW~ 그먼데?
# 1     자기직전에...엄마한테 붙들려서 자전거 한시간 타고왔다...... 자전거 한시간.....
# 2     웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 ...
# 3     지훊 불면제로에서 썰 푸는거 지짜 젛음 걍 존나 사랑하게 돼 ㅋ ㅋ ㅋ  비슷한 맥...
# ...

# %%
tw_bmw["hashtag"] = tw_bmw["tweet"].str.findall("#([0-9a-zA-Z가-힣]*)")

# %%
tw_bmw
# Out:
#                        id                       date  \
# 0     1416542776301297664  2021-07-17 23:38:10+00:00
# 1     1416538520739405826  2021-07-17 23:21:16+00:00
# 2     1416528562383773698  2021-07-17 22:41:41+00:00
# 3     1416457850642067457  2021-07-17 18:00:42+00:00
# 4     1416454660517359616  2021-07-17 17:48:02+00:00
# ...                   ...                        ...
# 6619  1212270892991963137  2020-01-01 07:14:38+00:00
# 6620  1212225587860738048  2020-01-01 04:14:36+00:00
# 6621  1212218663580782592  2020-01-01 03:47:05+00:00
# 6622  1212202142850699264  2020-01-01 02:41:27+00:00
# 6623  1212161592961318912  2020-01-01 00:00:19+00:00
#
#                                                   tweet hashtag
# 0                          나랑 일하면 BMW 탄다 // 오 BMW~ 그먼데?      []
# 1     자기직전에...엄마한테 붙들려서 자전거 한시간 타고왔다...... 자전거 한시간.....      []
# 2     웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 ...      []
# 3     지훊 불면제로에서 썰 푸는거 지짜 젛음 걍 존나 사랑하게 돼 ㅋ ㅋ ㅋ  비슷한 맥...      []
# ...

# %%
tw_bmw["hashtag"]
# Out:
# 0       []
# 1       []
# 2       []
# 3       []
# 4       []
#         ..
# 6619    []
# 6620    []
# 6621    []
# 6622    []
# 6623    []
# Name: hashtag, Length: 6624, dtype: object

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'BMW'
#Open/create a file to append data to
csvFile = open('2020_BMW_Twt.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2020-01-01 until:2020-12-31 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
bmw_twt_2020 = pd.read_csv("./2020_BMW_Twt.csv")

# %%
bmw_twt_2020
# Out:
#                        id                       date  \
# 0     1344306980089806848  2020-12-30 15:38:54+00:00
# 1     1344297841540222976  2020-12-30 15:02:35+00:00
# 2     1344127054522929152  2020-12-30 03:43:57+00:00
# 3     1343937184450015233  2020-12-29 15:09:28+00:00
# 4     1343887111804526592  2020-12-29 11:50:30+00:00
# ...                   ...                        ...
# 5340  1212270892991963137  2020-01-01 07:14:38+00:00
# 5341  1212225587860738048  2020-01-01 04:14:36+00:00
# 5342  1212218663580782592  2020-01-01 03:47:05+00:00
# 5343  1212202142850699264  2020-01-01 02:41:27+00:00
# 5344  1212161592961318912  2020-01-01 00:00:19+00:00
#
#                                                   tweet
# 0     아까 엄마 픽업하고 주차하려는데 11시쯤이라 주차구역이 1도없는거임 그래서 뱅뱅 돌...
# 1     오늘 현찰로 bmw산 언니가 자기남편이 볼보주문했다고 투덜투덜거리길래..\n\n부럽...
# 2     근데 내가 승석 포타 \n진짜 마니 읽으면서\n느낀건디...\n조승연 갖고 포타 진...
# 3     주작 가능성이 농후하긴 하지. BMW 추돌에 230만원이란 견적도 이상해 그리고 신...
# ...

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'BMW'
#Open/create a file to append data to
csvFile = open('2019_BMW_Twt.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2019-01-01 until:2019-12-31 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
bmw_twt_2019 = pd.read_csv("./2019_BMW_Twt.csv")

# %%
bmw_twt_2019
# Out:
#                        id                       date  \
# 0     1211786149888286720  2019-12-30 23:08:26+00:00
# 1     1211700362832302080  2019-12-30 17:27:33+00:00
# 2     1211675065789534209  2019-12-30 15:47:02+00:00
# 3     1211667424296091649  2019-12-30 15:16:40+00:00
# 4     1211655074419593216  2019-12-30 14:27:35+00:00
# ...                   ...                        ...
# 5630  1079951932041572352  2019-01-01 04:06:19+00:00
# 5631  1079927145042866176  2019-01-01 02:27:50+00:00
# 5632  1079907923243847680  2019-01-01 01:11:27+00:00
# 5633  1079903450236743680  2019-01-01 00:53:40+00:00
# 5634  1079891588631818240  2019-01-01 00:06:32+00:00
#
#                                                   tweet
# 0     현대차, 전기차 세계8위→3위···정의선 승부수 통했다.올해 전동화 차량(순수전기차...
# 1     #그ㄹㅐ프ㄱㅔ임꽁머니\n#소셜그ㄹㅐ프ㄱㅔ임주소\n⥏ ⥐ ⥑  ⤶ busTA5,COM...
# 2                              [신차] BMW 코리아, 뉴 X3 공식 출시
# 3                          송해 장수비결, 누구나 탈 수 있는 BMW가 해답?
# ...

# %%
bmw_twt_2019["tweet"].value_counts()
# Out:
# 웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 주소창에 가상리그.COM 를 치세요.                                                                                         697
# #그ㄹㅐ프ㄱㅔ임꽁머니\n#소셜그ㄹㅐ프ㄱㅔ임주소\n⥏ ⥐ ⥑  ⤶ busTA5,COM ⤷⥏ ⥐ ⥑ \n♊️코드: bmw5 ❇️\nM\n♉검증업체♉\n\n⤵⛈⤵\n\n그ㄹㅐ프게임 강력 추천 ㅅㅏㅇㅣ트\nFDFG ##그ㄹㅐ프ㄱㅔ임본사                            453
# #그ㄹㅐ프ㄱㅔ임꽁머니\n#소셜그ㄹㅐ프ㄱㅔ임주소\n⥏ ⥐ ⥑  ⤶ busTA5,COM ⤷⥏ ⥐ ⥑ \n♊️코드: bmw5 ❇️\nM\n♉검증업체♉\n\n⤵⛈⤵\n\n그ㄹㅐ프게임 강력 추천 ㅅㅏㅇㅣ트\nFDFG ##엔젤라인추천코드                             451
# 나랑 일하면. BMW 탄다!                                                                                                                                            357
# BMW 못타고 다니겠어. 절대 Bus Metro Walking 아니야.                                                                                                                    228
#                                                                                                                                                           ...
# ...

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'BMW'
#Open/create a file to append data to
csvFile = open('2018_BMW_Twt.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2018-01-01 until:2018-12-31 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
bmw_twt_2018 = pd.read_csv("./2018_BMW_Twt.csv")

# %%
bmw_twt_2018
# Out:
#                        id                       date  \
# 0     1079411494469521408  2018-12-30 16:18:49+00:00
# 1     1079385729833168898  2018-12-30 14:36:26+00:00
# 2     1079348147221016576  2018-12-30 12:07:06+00:00
# 3     1079346475375648768  2018-12-30 12:00:27+00:00
# 4     1079341688840056833  2018-12-30 11:41:26+00:00
# ...                   ...                        ...
# 7442   947795413058306049  2018-01-01 11:43:30+00:00
# 7443   947793678126399488  2018-01-01 11:36:36+00:00
# 7444   947728311894999042  2018-01-01 07:16:52+00:00
# 7445   947680421646548992  2018-01-01 04:06:34+00:00
# 7446   947674104118755328  2018-01-01 03:41:28+00:00
#
#                                                   tweet
# 0                  내년 자동차시장 달굴 신차는…현대 QX·BMW X5 등 출격 대기
# 1                                       나랑 일하면. BMW 탄다!
# 2                                      오~ BMW? ...거 뭔데?
# 3     #runpeople15 선릉-BMW #runpeople15 #runbest001㎤#...
# ...

# %%
bmw_twt_2018["tweet"].value_counts()
# Out:
# 웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 주소창에 가상리그.COM 를 치세요.                                                                                                                           697
# #그ㄹㅐ프ㄱㅔ임꽁머니\n#소셜그ㄹㅐ프ㄱㅔ임주소\n⥏ ⥐ ⥑  ⤶ busTA5,COM ⤷⥏ ⥐ ⥑ \n♊️코드: bmw5 ❇️\nM\n♉검증업체♉\n\n⤵⛈⤵\n\n그ㄹㅐ프게임 강력 추천 ㅅㅏㅇㅣ트\nFDFG ##그ㄹㅐ프ㄱㅔ임본사                                                              462
# #그ㄹㅐ프ㄱㅔ임꽁머니\n#소셜그ㄹㅐ프ㄱㅔ임주소\n⥏ ⥐ ⥑  ⤶ busTA5,COM ⤷⥏ ⥐ ⥑ \n♊️코드: bmw5 ❇️\nM\n♉검증업체♉\n\n⤵⛈⤵\n\n그ㄹㅐ프게임 강력 추천 ㅅㅏㅇㅣ트\nFDFG ##엔젤라인추천코드                                                               440
# 나랑 일하면. BMW 탄다!                                                                                                                                                                              361
# BMW 못타고 다니겠어. 절대 Bus Metro Walking 아니야.                                                                                                                                                      247
# ...

# %%
# Set maximum tweets to pull
maxTweets = 20000
# Set what keywords you want your twitter scraper to pull
keyword = 'BMW'
#Open/create a file to append data to
csvFile = open('2017_BMW_Twt.csv', 'a', newline='', encoding='utf8')
#Use csv writer
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',])

# Write tweets into the csv file
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(keyword + ' lang:ko since:2017-01-01 until:2017-12-31 -filter:links -filter:replies').get_items()):
        if i > maxTweets :
            break  
        csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()

# %%
bmw_twt_2017 = pd.read_csv("./2017_BMW_Twt.csv")

# %%
bmw_twt_2017
# Out:
#                       id                       date  \
# 0     947107875649871873  2017-12-30 14:11:28+00:00
# 1     947093580975243265  2017-12-30 13:14:40+00:00
# 2     947091530526769155  2017-12-30 13:06:31+00:00
# 3     947069029327319040  2017-12-30 11:37:06+00:00
# 4     947063939560456192  2017-12-30 11:16:53+00:00
# ...                  ...                        ...
# 4631  815419640029401088  2017-01-01 04:49:26+00:00
# 4632  815388085315739652  2017-01-01 02:44:03+00:00
# 4633  815385069829296128  2017-01-01 02:32:04+00:00
# 4634  815381432868556800  2017-01-01 02:17:37+00:00
# 4635  815363827373965312  2017-01-01 01:07:39+00:00
#
#                                                   tweet
# 0     웹가상리그 / 프로레슬링 가상리그 / BMw 가상리그 를 만나보고 싶으시면 인터넷 ...
# 1                   졸아서 찍힌 사진 아냐"..장수비결 알고보니 "BMW가 뭐...
# 2                                       나랑 일하면. BMW 탄다!
# 3                                      오~ BMW? ...거 뭔데?
# ...

# %% [markdown]
# https://biz.chosun.com/international/international_general/2021/06/16/Z3VO6I2GENFENG577CH7EZWUJE/
#
# https://biz.chosun.com/site/data/html_dir/2020/09/07/2020090700514.html
