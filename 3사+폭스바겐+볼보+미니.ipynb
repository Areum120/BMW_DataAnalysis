# %% [markdown]
# ## 유럽6사 합치기 ##

# %%
import os
import pandas as pd

# %% [markdown]
# ### 파일 불러오기 ###

# %%
df0 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\europe6_model_year/07. 2017~2021(1~5월)_BMW_모델_연도별_판매량.csv', encoding='utf-8')
df0
# bmw
# Out:
#      Unnamed: 0  year  car_name     sub_name quentity
# 0             0  2017  5 Series         520d   10,249
# 1             1  2017  5 Series  520d xDrive    5,712
# 2             2  2017  5 Series  530i xDrive    4,690
# 3             3  2017  5 Series         530i    4,560
# 4             4  2017  5 Series         530d      569
# ..          ...   ...       ...          ...      ...
# 615         118  2021  5 Series         530d        1
# 616         119  2021        M3          3.0        7
# 617         120  2021        M3          3.0        7
# 618         121  2021        M4     M4 Coupe        6
# 619         122  2021        M4     M4 Coupe        6
#
# [620 rows x 5 columns]

# %%
df1 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\europe6_model_year/08. 2017~2021(1~5월)_MB_모델_연도별_판매량.csv', encoding='utf-8')
df1
# benz
# Out:
#      Unnamed: 0  year car_name      sub_name quentity
# 0             0  2017  E-Class   E300 4MATIC    8,806
# 1             1  2017  E-Class         E220d    6,530
# 2             2  2017  E-Class          E300    6,299
# 3             3  2017  E-Class          E200    4,737
# 4             4  2017  E-Class  E220d 4MATIC    4,645
# ..          ...   ...      ...           ...      ...
# 577          95  2021  Maybach  S650 Pullman       10
# 578          96  2021  Maybach   S560 4MATIC        3
# 579          97  2021  Maybach          S650        2
# 580          98  2021  Maybach   S500 4MATIC        1
# 581          99  2021  Maybach   S500 4MATIC        1
#
# [582 rows x 5 columns]

# %%
df2 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\europe6_model_year/09. 2017~2021(1~5월)_Audi_모델_연도별_판매량.csv', encoding='utf-8')
df2
# Audi
# Out:
#      Unnamed: 0  year         car_name         sub_name quentity
# 0             0  2017               A7   50 TDI quattro      627
# 1             1  2017               A7           40 TDI       36
# 2             2  2017               A7   55 TDI quattro       22
# 3             3  2017               A7  50 TFSI quattro        8
# 4             4  2017               A7  50 TFSI quattro        8
# ..          ...   ...              ...              ...      ...
# 169          50  2021               Q3           35 TDI       27
# 170          51  2021               Q2           35 TDI       38
# 171          52  2021               Q2           35 TDI       38
# 172          53  2021  The new audi R8  V10 performance       32
# 173          54  2021  The new audi R8  V10 performance       32
#
# [174 rows x 5 columns]

# %%
df3 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\europe6_model_year/Volkswagen2017_2021.csv', encoding='utf-8')
df3
# volks
# Out:
#     Unnamed: 0  year           car_name          sub_name quentity
# 0            0  2018             Tiguan           2.0 TDI    4,567
# 1            1  2018             Tiguan   2.0 TDI 4Motion    2,010
# 2            2  2018             Tiguan  Allspace 2.0 TDI      928
# 3            3  2018             Tiguan  Allspace 2.0 TDI      928
# 4            4  2018             Passat           2.0 TSI    4,387
# 5            5  2018             Passat           2.0 TSI    4,387
# 6            6  2018          Passat GT           2.0 TDI    2,534
# 7            7  2018          Passat GT   2.0 TDI 4Motion      588
# 8            8  2018          Passat GT   2.0 TDI 4Motion      588
# 9            9  2018             Arteon           2.0 TDI      780
# 10          10  2018             Arteon           2.0 TDI      780
# 11           0  2019             Arteon           2.0 TDI    6,784
# 12           1  2019             Arteon           2.0 TDI    6,784
# ...

# %%
df4 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\europe6_model_year/Mini2017_2021.csv', encoding='utf-8')
df4
# mini
# Out:
#      Unnamed: 0  year     car_name            sub_name quentity
# 0             0  2017        Hatch              Cooper    1,248
# 1             1  2017        Hatch    Cooper five-door    1,245
# 2             2  2017        Hatch            Cooper D      892
# 3             3  2017        Hatch  Cooper D five-door      887
# 4             4  2017        Hatch   John Cooper Works      243
# ..          ...   ...          ...                 ...      ...
# 130          17  2021      Clubman           Cooper SD        6
# 131          18  2021  Convertible            Cooper S       62
# 132          19  2021  Convertible   John Cooper Works       41
# 133          20  2021  Convertible              Cooper       22
# 134          21  2021  Convertible              Cooper       22
#
# [135 rows x 5 columns]

# %%
df5 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\europe6_model_year/Volvo2017_2021.csv', encoding='utf-8')
df5
# mini
# Out:
#      Unnamed: 0  year           car_name    sub_name quentity
# 0             0  2017                S90      2.0 D4      597
# 1             1  2017                S90      2.0 T5      493
# 2             2  2017                S90  2.0 D5 AWD      452
# 3             3  2017                S90  2.0 D5 AWD      452
# 4             4  2017                S60      2.0 D3      785
# ..          ...   ...                ...         ...      ...
# 150          16  2021  V90 Cross Country      B5 AWD      205
# 151          17  2021  V90 Cross Country      B6 AWD        7
# 152          18  2021  V90 Cross Country      B6 AWD        7
# 153          19  2021                S90  2.0 T8 AWD       53
# 154          20  2021                S90  2.0 T8 AWD       53
#
# [155 rows x 5 columns]

# %%
# 컬럼명변경
df0 = df0.rename({'Unnamed: 0': 'brand'}, axis=1)
df1 = df1.rename({'Unnamed: 0': 'brand'}, axis=1)
df2 = df2.rename({'Unnamed: 0': 'brand'}, axis=1)
df3 = df3.rename({'Unnamed: 0': 'brand'}, axis=1)
df4 = df4.rename({'Unnamed: 0': 'brand'}, axis=1)
df5 = df5.rename({'Unnamed: 0': 'brand'}, axis=1)

# %%
df0['brand']='BMW'
df1['brand']='MB'
df2['brand']='Audi'
df3['brand']='Volkswagen'
df4['brand']='Mini'
df5['brand']='Volvo'

# %%
df0
# Out:
#     brand  year  car_name     sub_name quentity
# 0     BMW  2017  5 Series         520d   10,249
# 1     BMW  2017  5 Series  520d xDrive    5,712
# 2     BMW  2017  5 Series  530i xDrive    4,690
# 3     BMW  2017  5 Series         530i    4,560
# 4     BMW  2017  5 Series         530d      569
# ..    ...   ...       ...          ...      ...
# 615   BMW  2021  5 Series         530d        1
# 616   BMW  2021        M3          3.0        7
# 617   BMW  2021        M3          3.0        7
# 618   BMW  2021        M4     M4 Coupe        6
# 619   BMW  2021        M4     M4 Coupe        6
#
# [620 rows x 5 columns]

# %%
df1
# Out:
#     brand  year car_name      sub_name quentity
# 0      MB  2017  E-Class   E300 4MATIC    8,806
# 1      MB  2017  E-Class         E220d    6,530
# 2      MB  2017  E-Class          E300    6,299
# 3      MB  2017  E-Class          E200    4,737
# 4      MB  2017  E-Class  E220d 4MATIC    4,645
# ..    ...   ...      ...           ...      ...
# 577    MB  2021  Maybach  S650 Pullman       10
# 578    MB  2021  Maybach   S560 4MATIC        3
# 579    MB  2021  Maybach          S650        2
# 580    MB  2021  Maybach   S500 4MATIC        1
# 581    MB  2021  Maybach   S500 4MATIC        1
#
# [582 rows x 5 columns]

# %%
df2
# Out:
#     brand  year         car_name         sub_name quentity
# 0    Audi  2017               A7   50 TDI quattro      627
# 1    Audi  2017               A7           40 TDI       36
# 2    Audi  2017               A7   55 TDI quattro       22
# 3    Audi  2017               A7  50 TFSI quattro        8
# 4    Audi  2017               A7  50 TFSI quattro        8
# ..    ...   ...              ...              ...      ...
# 169  Audi  2021               Q3           35 TDI       27
# 170  Audi  2021               Q2           35 TDI       38
# 171  Audi  2021               Q2           35 TDI       38
# 172  Audi  2021  The new audi R8  V10 performance       32
# 173  Audi  2021  The new audi R8  V10 performance       32
#
# [174 rows x 5 columns]

# %%
df3
# Out:
#          brand  year           car_name          sub_name quentity
# 0   Volkswagen  2018             Tiguan           2.0 TDI    4,567
# 1   Volkswagen  2018             Tiguan   2.0 TDI 4Motion    2,010
# 2   Volkswagen  2018             Tiguan  Allspace 2.0 TDI      928
# 3   Volkswagen  2018             Tiguan  Allspace 2.0 TDI      928
# 4   Volkswagen  2018             Passat           2.0 TSI    4,387
# 5   Volkswagen  2018             Passat           2.0 TSI    4,387
# 6   Volkswagen  2018          Passat GT           2.0 TDI    2,534
# 7   Volkswagen  2018          Passat GT   2.0 TDI 4Motion      588
# 8   Volkswagen  2018          Passat GT   2.0 TDI 4Motion      588
# 9   Volkswagen  2018             Arteon           2.0 TDI      780
# 10  Volkswagen  2018             Arteon           2.0 TDI      780
# 11  Volkswagen  2019             Arteon           2.0 TDI    6,784
# 12  Volkswagen  2019             Arteon           2.0 TDI    6,784
# ...

# %%
df4
# Out:
#     brand  year     car_name            sub_name quentity
# 0    Mini  2017        Hatch              Cooper    1,248
# 1    Mini  2017        Hatch    Cooper five-door    1,245
# 2    Mini  2017        Hatch            Cooper D      892
# 3    Mini  2017        Hatch  Cooper D five-door      887
# 4    Mini  2017        Hatch   John Cooper Works      243
# ..    ...   ...          ...                 ...      ...
# 130  Mini  2021      Clubman           Cooper SD        6
# 131  Mini  2021  Convertible            Cooper S       62
# 132  Mini  2021  Convertible   John Cooper Works       41
# 133  Mini  2021  Convertible              Cooper       22
# 134  Mini  2021  Convertible              Cooper       22
#
# [135 rows x 5 columns]

# %%
df5
# Out:
#      brand  year           car_name    sub_name quentity
# 0    Volvo  2017                S90      2.0 D4      597
# 1    Volvo  2017                S90      2.0 T5      493
# 2    Volvo  2017                S90  2.0 D5 AWD      452
# 3    Volvo  2017                S90  2.0 D5 AWD      452
# 4    Volvo  2017                S60      2.0 D3      785
# ..     ...   ...                ...         ...      ...
# 150  Volvo  2021  V90 Cross Country      B5 AWD      205
# 151  Volvo  2021  V90 Cross Country      B6 AWD        7
# 152  Volvo  2021  V90 Cross Country      B6 AWD        7
# 153  Volvo  2021                S90  2.0 T8 AWD       53
# 154  Volvo  2021                S90  2.0 T8 AWD       53
#
# [155 rows x 5 columns]

# %%
# 합치기
result = pd.concat([df0, df1, df2, df3, df4, df5])
result
# Out:
#      brand  year           car_name     sub_name quentity
# 0      BMW  2017           5 Series         520d   10,249
# 1      BMW  2017           5 Series  520d xDrive    5,712
# 2      BMW  2017           5 Series  530i xDrive    4,690
# 3      BMW  2017           5 Series         530i    4,560
# 4      BMW  2017           5 Series         530d      569
# ..     ...   ...                ...          ...      ...
# 150  Volvo  2021  V90 Cross Country       B5 AWD      205
# 151  Volvo  2021  V90 Cross Country       B6 AWD        7
# 152  Volvo  2021  V90 Cross Country       B6 AWD        7
# 153  Volvo  2021                S90   2.0 T8 AWD       53
# 154  Volvo  2021                S90   2.0 T8 AWD       53
#
# [1715 rows x 5 columns]

# %%
result.to_csv("europe6_2017_2021.csv")
