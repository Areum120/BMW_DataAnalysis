# %%
import os
import pandas as pd

# %% [markdown]
# ### bmw ###

# %% [markdown]
# ### 파일 불러오기 ###

# %%
df0 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/0.csv', encoding='utf-8')
df0
# 2017
# Out:
#      Unnamed: 0  car_name     sub_name quentity
# 0             0  5 Series         520d   10,249
# 1             1  5 Series  520d xDrive    5,712
# 2             2  5 Series  530i xDrive    4,690
# 3             3  5 Series         530i    4,560
# 4             4  5 Series         530d      569
# ..          ...       ...          ...      ...
# 99           99        i8          1.5      123
# 100         100        i8          1.5      123
# 101         101        Z4        3.5 S        3
# 102         102        Z4          2.8        2
# 103         103        Z4          2.8        2
#
# [104 rows x 4 columns]

# %%
df1 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/1.csv', encoding='utf-8')
df1
# 2018
# Out:
#     Unnamed: 0  car_name     sub_name quentity
# 0            0  5 Series         520d    7,704
# 1            1  5 Series  530i xDrive    4,400
# 2            2  5 Series         530i    4,248
# 3            3  5 Series  520d xDrive    3,870
# 4            4  5 Series         520i    2,929
# ..         ...       ...          ...      ...
# 95          95        X2          20d       54
# 96          96        M3          3.0       34
# 97          97        M3          3.0       34
# 98          98        i3           EV        2
# 99          99        i3           EV        2
#
# [100 rows x 4 columns]

# %%
df2 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/2.csv', encoding='utf-8')
df2
# 2019
# Out:
#      Unnamed: 0  car_name     sub_name quentity
# 0             0  5 Series         520i    5,792
# 1             1  5 Series         530i    4,179
# 2             2  5 Series  530i xDrive    3,956
# 3             3  5 Series         520d    3,059
# 4             4  5 Series  520d xDrive    1,776
# ..          ...       ...          ...      ...
# 139         139        i8  i8 Roadster        9
# 140         140        i8     i8 Coupe        1
# 141         141        i8     i8 Coupe        1
# 142         142        M8     M8 Coupe        6
# 143         143        M8     M8 Coupe        6
#
# [144 rows x 4 columns]

# %%
df3 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/3.csv', encoding='utf-8')
df3
# 2020
# Out:
#      Unnamed: 0  car_name       sub_name quentity
# 0             0  5 Series           520i    5,141
# 1             1  5 Series           520d    2,849
# 2             2  5 Series           530i    2,726
# 3             3  5 Series    530i xDrive    1,741
# 4             4  5 Series    520d xDrive    1,307
# ..          ...       ...            ...      ...
# 144         144        M5             M5       13
# 145         145        M5             M5       13
# 146         146      X6 M           X6 M        4
# 147         147      X6 M  트림별 판매량 분류 예정        2
# 148         148      X6 M  트림별 판매량 분류 예정        2
#
# [149 rows x 4 columns]

# %%
df4 = pd.read_csv('C:\\Users\\웍스컴바인\\Desktop\\work\\data_analysis\\DanawaCrawler\\crawl_result\\json\\europe6\\csv파일/4.csv', encoding='utf-8')
df4
# 2021
# Out:
#      Unnamed: 0  car_name     sub_name quentity
# 0             0  5 Series         520i    3,114
# 1             1  5 Series         530e    2,010
# 2             2  5 Series         530i    1,731
# 3             3  5 Series  530i xDrive      958
# 4             4  5 Series         523d      653
# ..          ...       ...          ...      ...
# 118         118  5 Series         530d        1
# 119         119        M3          3.0        7
# 120         120        M3          3.0        7
# 121         121        M4     M4 Coupe        6
# 122         122        M4     M4 Coupe        6
#
# [123 rows x 4 columns]

# %% [markdown]
# ### 컬럼명,값 변경 ###

# %%
# 컬럼명변경
df0 = df0.rename({'Unnamed: 0': 'year'}, axis=1)

# %%
df1 = df1.rename({'Unnamed: 0': 'year'}, axis=1)

# %%
df2 = df2.rename({'Unnamed: 0': 'year'}, axis=1)

# %%
df3 = df3.rename({'Unnamed: 0': 'year'}, axis=1)

# %%
df4 = df4.rename({'Unnamed: 0': 'year'}, axis=1)

# %%
df0["year"]=2017
df0
# Out:
#      year  car_name     sub_name quentity
# 0    2017  5 Series         520d   10,249
# 1    2017  5 Series  520d xDrive    5,712
# 2    2017  5 Series  530i xDrive    4,690
# 3    2017  5 Series         530i    4,560
# 4    2017  5 Series         530d      569
# ..    ...       ...          ...      ...
# 99   2017        i8          1.5      123
# 100  2017        i8          1.5      123
# 101  2017        Z4        3.5 S        3
# 102  2017        Z4          2.8        2
# 103  2017        Z4          2.8        2
#
# [104 rows x 4 columns]

# %%
df1["year"]=2018
df1
# Out:
#     year  car_name     sub_name quentity
# 0   2018  5 Series         520d    7,704
# 1   2018  5 Series  530i xDrive    4,400
# 2   2018  5 Series         530i    4,248
# 3   2018  5 Series  520d xDrive    3,870
# 4   2018  5 Series         520i    2,929
# ..   ...       ...          ...      ...
# 95  2018        X2          20d       54
# 96  2018        M3          3.0       34
# 97  2018        M3          3.0       34
# 98  2018        i3           EV        2
# 99  2018        i3           EV        2
#
# [100 rows x 4 columns]

# %%
df2["year"]=2019
df2
# Out:
#      year  car_name     sub_name quentity
# 0    2019  5 Series         520i    5,792
# 1    2019  5 Series         530i    4,179
# 2    2019  5 Series  530i xDrive    3,956
# 3    2019  5 Series         520d    3,059
# 4    2019  5 Series  520d xDrive    1,776
# ..    ...       ...          ...      ...
# 139  2019        i8  i8 Roadster        9
# 140  2019        i8     i8 Coupe        1
# 141  2019        i8     i8 Coupe        1
# 142  2019        M8     M8 Coupe        6
# 143  2019        M8     M8 Coupe        6
#
# [144 rows x 4 columns]

# %%
df3["year"]=2020
df3
# Out:
#      year  car_name       sub_name quentity
# 0    2020  5 Series           520i    5,141
# 1    2020  5 Series           520d    2,849
# 2    2020  5 Series           530i    2,726
# 3    2020  5 Series    530i xDrive    1,741
# 4    2020  5 Series    520d xDrive    1,307
# ..    ...       ...            ...      ...
# 144  2020        M5             M5       13
# 145  2020        M5             M5       13
# 146  2020      X6 M           X6 M        4
# 147  2020      X6 M  트림별 판매량 분류 예정        2
# 148  2020      X6 M  트림별 판매량 분류 예정        2
#
# [149 rows x 4 columns]

# %%
df4["year"]=2021
df4
# Out:
#      year  car_name     sub_name quentity
# 0    2021  5 Series         520i    3,114
# 1    2021  5 Series         530e    2,010
# 2    2021  5 Series         530i    1,731
# 3    2021  5 Series  530i xDrive      958
# 4    2021  5 Series         523d      653
# ..    ...       ...          ...      ...
# 118  2021  5 Series         530d        1
# 119  2021        M3          3.0        7
# 120  2021        M3          3.0        7
# 121  2021        M4     M4 Coupe        6
# 122  2021        M4     M4 Coupe        6
#
# [123 rows x 4 columns]

# %%
# 합치기
result = pd.concat([df0, df1, df2, df3, df4])
result
# Out:
#      year  car_name     sub_name quentity
# 0    2017  5 Series         520d   10,249
# 1    2017  5 Series  520d xDrive    5,712
# 2    2017  5 Series  530i xDrive    4,690
# 3    2017  5 Series         530i    4,560
# 4    2017  5 Series         530d      569
# ..    ...       ...          ...      ...
# 118  2021  5 Series         530d        1
# 119  2021        M3          3.0        7
# 120  2021        M3          3.0        7
# 121  2021        M4     M4 Coupe        6
# 122  2021        M4     M4 Coupe        6
#
# [620 rows x 4 columns]

# %%
result.to_csv("bmw2017_2021.csv")
